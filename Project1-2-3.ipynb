# %%
##project2.1-2-3.ipynb
##charles wiredu
import pandas as pd
import matplotlib.pyplot as plot
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
from PIL import Image
import random

num_1s= 0
num_2s= 0
num_3s= 0
num_4s= 0
num_5s= 0
num_6s= 0
num_7s= 0
num_8s= 0
num_9s= 0

d= {}
def menu():
    '''The user is presented with three options '''
    print('Choose from the following options: ')

    
def cloud():
    '''a word cloud of the top 100 most common words'''
    print('The word cloud for 100 most common words of the file')

while True:
    def chart():
        '''displays a chart of the number of words of each length'''
        print('The chart of words of each length')
        
    def long():
        '''lists the 10 longest words in a text file'''
        print('The 10 longest words are;')
        #fmax_len= len(max(words, key=len))
    
    Num_of_words=0
    num_words_2= 0
    wordcount={}
    menu()
    user_input=print('''
    Menu
    1. Analysze a local, user specified file.
    2. Connect to Project Gutenberg and analysze the U.S. Constitution.
    3. Connect to Project Gutenberg and analyze the State of the Union Addresses for a specific President.
    4. Quit the program
    ''')
    user_input= int(input('Enter your choice: '))
    if user_input== 1:
        print("Analysze a local, user specified file.")
        try:
            filename= input('Enter a filename to open(file must be in current directory):  ')
            with open(filename, 'r') as datafile:
                # read one line from the file at a time(includes the '\n' at the end of the line )
                for eachline in datafile:
                    eachline = datafile.read()
                    eachline= eachline.lower()
                    #print(eachline)
                    eachline_lower=eachline.replace("!"," ")
                    eachline_lower=eachline_lower.replace("."," ")
                    eachline_lower=eachline_lower.replace("\n"," ")
                    eachline_lower=eachline_lower.replace(","," ")
                    eachline_lower=eachline_lower.replace(":"," ")
                    eachline_lower=eachline_lower.replace("&"," ")
                    eachline_lower=eachline_lower.replace("*"," ")
                    eachline_lower=eachline_lower.replace("%"," ")
                    eachline_lower=eachline_lower.replace("?"," ")
                    eachline_lower=eachline_lower.replace("/"," ")
                    eachline_lower=eachline_lower.replace("-"," ")
                    eachline_lower=eachline_lower.replace("@"," ")
                    eachline_lower=eachline_lower.replace("#"," ")
                    eachline_lower=eachline_lower.replace("[]"," ")
                    eachline_lower=eachline_lower.replace("~5"," ")
                    eachline_lower=eachline_lower.replace("'"," ")
                    #print(eachline_lower)
                    words= eachline_lower.split()
                    #print(words)
                    maximum= max(words, key=len)
                    minimum= min(words, key=len)
                    #print('the maximum is ', len(maximum))
                    Num_of_words += len(words)
                    for word in set(words):
                        num_words_2 += 1
                    #print(num_words_2)total unique words
                    ## finding average
                    average = Num_of_words/num_words_2
                    
                    for word in words:
                        if word not in d:
                            d[word]= 1 
                        else:
                            d[word] += 1 
                    
                    #the top 10 longest words 
                    long_words=sorted(words,key= len, reverse=True)
                    #print(long_words)
                    ##without duplication 
                    long_words1= list(dict.fromkeys(long_words))
                    long_words_10= long_words1[:10]
                    for  word in range (d[word]):
                        word= random.randrange(1,10)
                        if word==1:
                            num_1s += 1
                        elif word==2:
                            num_2s += 1
                        elif word==3:
                            num_3s += 1
                        elif word==4:
                            num_4s += 1
                        elif word==5:
                            num_5s += 1
                        elif word==6:
                            num_6s += 1
                        elif word==7:
                            num_7s += 1
                        elif word==8:
                            num_8s += 1
                        elif word==9:
                            num_9s += 1
                    
                print('There are a total of',Num_of_words, 'words in this selection.')
                print()
                print('There are', len(set(words)), 'unique words in this selection.')
                print()
                print('The average word length is',  round(average,2))
                print()
                print('The minimum length is', len(minimum) ,'and the maximum length is', len(maximum))
                print()
                long()
                print(long_words_10)    
                
                print("The longest word is", long_words_10[0], "and was found", long_words.count(long_words_10[0]), "time")
                print("The 2nd is", long_words_10[1], "and was found", long_words.count(long_words_10[1]), "time")
                print("The 3rd is", long_words_10[2], "and was found", long_words.count(long_words_10[2]), "times")
                print("The 4th is", long_words_10[3], "and was found", long_words.count(long_words_10[3]), "time")
                print("The 5th is", long_words_10[4], "and was found", long_words.count(long_words_10[4]), "time")
                print("The 6th is", long_words_10[5], "and was found", long_words.count(long_words_10[5]), "time")
                print("The 7th is", long_words_10[6], "and was found", long_words.count(long_words_10[6]), "times")
                print("The 8th is", long_words_10[7], "and was found", long_words.count(long_words_10[7]), "times")
                print("The 9th is", long_words_10[8], "and was found", long_words.count(long_words_10[8]), "time")
                print("The 10th is", long_words_10[9], "and was found", long_words.count(long_words_10[9]), "time")
                print()
                print('=======================================')
                chart()
                print('=======================================')
                print(f'Word       {"length of each word":>10}')
                print(f'{1:>4}      {num_1s:>10}')
                print(f'{2:>4}      {num_2s:>10}')
                print(f'{3:>4}      {num_3s:>10}')
                print(f'{4:>4}      {num_4s:>10}')
                print(f'{5:>4}      {num_5s:>10}')
                print(f'{6:>4}      {num_6s:>10}')
                print(f'{7:>4}      {num_7s:>10}')
                print(f'{8:>4}      {num_8s:>10}')
                print(f'{9:>4}      {num_9s:>10}')
                # display the results as a graph
             
                figure = plot.figure()  # start with a blank figure
                axes = figure.add_axes([1,1,2,2])
                labels = ['1','2','3','4','5','6','7','8','9']
                values = [num_1s,num_2s,num_3s,num_4s,num_5s,num_6s,num_7s,num_8s,num_9s]
                axes.bar(labels,values)
                axes.set_title('Number of words of each length')
                plot.show()
                
                print('==============================================================')
                cloud()
                print('==============================================================')
                from collections import Counter
                words_counts= Counter(words)
                top_100= words_counts.most_common(100)
                word_dict= {i:u for i, u in enumerate(top_100)}
                unique_string= ','.join(str(v) for v in top_100)
                wordcloud= WordCloud(width=1000,height=500,colormap='prism', background_color='white').generate(unique_string)
                plot.figure(figsize=(15,8))
                plot.imshow(wordcloud)
                plot.axis("off")
                plot.savefig("your_file_name"+".png", bbox_inches='tight')
                plot.show()
              
        except FileNotFoundError:
        ## if there is no file namee by that name,print an error
            print('there is no file named', filename, 'in this directory')
    elif user_input==2:
        print("Connect to Project Gutenberg and analysze the U.S. Constitution.") 
        ten= {}
        count_1=0
        count=0
        words_count= {}
        total_words= {}
        words_list= []
        keys_1= ()
        dict_x= {}
        import requests
        full_text = requests.get('https://www.gutenberg.org/cache/epub/5/pg5.txt').text
        # take this big block of text and convert to a list of strings, one line per string
        text_list = full_text.split('\n') 
        #print(text_list)
        # remove first 83 lines and end on line 676
        final_list = text_list[83:677]
        final_list= str(final_list)
        #print(color.BOLD +"\n Wordle Words:"+ color.END)
        ##removing all punctuations
        fixed_text = final_list.replace('$',' ')
        fixed_text = fixed_text.replace('&',' ')
        fixed_text = fixed_text.replace('%',' ')
        fixed_text = fixed_text.replace('-',' ')
        fixed_text = fixed_text.replace('_',' ')
        fixed_text = fixed_text.replace('=',' ')
        fixed_text = fixed_text.replace('+',' ')
        fixed_text = fixed_text.replace('<',' ')
        fixed_text = fixed_text.replace('>',' ')
        fixed_text = fixed_text.replace(''' " ''',' ')
        fixed_text = fixed_text.replace('(',' ')
        fixed_text = fixed_text.replace(')',' ')
        fixed_text = fixed_text.replace('~',' ')
        fixed_text = final_list.replace('\n',' ')  
        fixed_text = fixed_text.replace('.',' ')
        fixed_text = fixed_text.replace(';',' ')
        fixed_text = fixed_text.replace('?',' ')
        fixed_text = fixed_text.replace('!',' ')
        fixed_text = fixed_text.replace(',',' ')
        fixed_text = fixed_text.replace(':',' ')
        fixed_text = fixed_text.replace('*',' ')
        fixed_text = fixed_text.replace('/',' ')
        fixed_text = fixed_text.replace('[',' ')
        fixed_text = fixed_text.replace(']',' ')
        fixed_text = fixed_text.replace('#',' ')
        fixed_text = fixed_text.replace('@',' ')
        fixed_text = fixed_text.replace('\\',' ')
        fixed_text = fixed_text.replace("'",' ')
        fixed_text = fixed_text.replace("--",' ')
        fixed_text = fixed_text.replace("`",' ')
        fixed_text = fixed_text.replace('"',' ')
        
        #print(fixed_text)
        words_list= fixed_text.split()
        words_list1= [i.strip() for i in words_list]
        keys_1= list(words_count.keys())
        #print(words_list1)
        maximum= max(words_list1, key=len)
        #print(maximum)
        minimum= min(words_list1, key=len)
        #print(minimum)
        ##converting all to lower case
        for i in range(len(words_list1)):
            words_list1[i]= words_list1[i].lower()
        count += len(words_list1)
        for word in set(words_list1):
            count_1 += 1
        
        #print(num_words_2)total unique words
        ## finding average
        average1 = count/count_1
        #print(average1)
        for word in words_list1:
            if word.isalpha():
                if word in dict_x:
                    dict_x[word] += 1
                else:
                    dict_x[word] = 1
        #the top 10 longest words 
        long_words1=sorted(words_list1,key= len, reverse=True)
        #print(long_words)
        ##without duplication 
        long_words2= list(dict.fromkeys(long_words1))
        long_words_10= long_words2[:10]
        
        for  word in range (dict_x[word]):
            
            word= random.randrange(1,10)
            if word==1:
                num_1s += 1
            elif word==2:
                num_2s += 1
            elif word==3:
                num_3s += 1
            elif word==4:
                num_4s += 1
            elif word==5:
                num_5s += 1
            elif word==6:
                num_6s += 1
            elif word==7:
                num_7s += 1
            elif word==8:
                num_8s += 1
            elif word==9:
                num_9s += 1
        #print(long_words_10)
        print('====================================')
        print('ANALYSIS ON U.S CONSTITUTION ')
        print('====================================')
        
        print('There are a total of',count, 'words in this selection.')
        print()
        print('There are', len(set(words_list1)), 'unique words in this selection.')
        print()
        print('The average word length is',  round(average1,2))
        print()
        print('The minimum length is', len(minimum) ,'and the maximum length is', len(maximum))
        print()
                
        long()
        print(long_words_10)    
                
        print("The longest word is", long_words_10[0], "and was found", long_words1.count(long_words_10[0]), "time")
        print("The 2nd is", long_words_10[1], "and was found", long_words1.count(long_words_10[1]), "time")
        print("The 3rd is", long_words_10[2], "and was found", long_words1.count(long_words_10[2]), "times")
        print("The 4th is", long_words_10[3], "and was found", long_words1.count(long_words_10[3]), "time")
        print("The 5th is", long_words_10[4], "and was found", long_words1.count(long_words_10[4]), "time")
        print("The 6th is", long_words_10[5], "and was found", long_words1.count(long_words_10[5]), "time")
        print("The 7th is", long_words_10[6], "and was found", long_words1.count(long_words_10[6]), "times")
        print("The 8th is", long_words_10[7], "and was found", long_words1.count(long_words_10[7]), "times")
        print("The 9th is", long_words_10[8], "and was found", long_words1.count(long_words_10[8]), "time")
        print("The 10th is", long_words_10[9], "and was found", long_words1.count(long_words_10[9]), "time")
        
        print()
        print('=======================================')
        chart()
        print('=======================================')
        print(f'Word       {"length of each word":>10}')
        print(f'{1:>4}      {num_1s:>10}')
        print(f'{2:>4}      {num_2s:>10}')
        print(f'{3:>4}      {num_3s:>10}')
        print(f'{4:>4}      {num_4s:>10}')
        print(f'{5:>4}      {num_5s:>10}')
        print(f'{6:>4}      {num_6s:>10}')
        print(f'{7:>4}      {num_7s:>10}')
        print(f'{8:>4}      {num_8s:>10}')
        print(f'{9:>4}      {num_9s:>10}')
        # display the results as a graph
             
        figure = plot.figure()  # start with a blank figure
        axes = figure.add_axes([1,1,2,2])
        labels = ['1','2','3','4','5','6','7','8','9']
        values = [num_1s,num_2s,num_3s,num_4s,num_5s,num_6s,num_7s,num_8s,num_9s]
        axes.bar(labels,values)
        axes.set_title('Number of words of each length')
        plot.show()
        
        print('==============================================================')
        cloud()
        print('==============================================================')
        from collections import Counter
        words_counts_1= Counter(words_list1)
        top_100= words_counts_1.most_common(100)
        word_dict= {i:u for i, u in enumerate(top_100)}
        unique_string= ','.join(str(v) for v in top_100)
        wordcloud= WordCloud(width=1000,height=500,colormap='prism', background_color='white').generate(unique_string)
        plot.figure(figsize=(15,8))
        plot.imshow(wordcloud)
        plot.axis("off")
        plot.savefig("your_file_name"+".png", bbox_inches='tight')
        plot.show()
    elif user_input==3:
        print("Connect to Project Gutenberg and analyze the State of the Union Addresses for a specific President.")
        ten= {}
        count_1=0
        count=0
        words_count= {}
        total_words= {}
        words_list= []
        keys_1= ()
        dict_x= {}
        import requests
        full_text = requests.get('https://www.gutenberg.org/cache/epub/50950/pg50950.txt').text
        # take this big block of text and convert to a list of strings, one line per string
        text_list = full_text.split('\n') 
        #print(text_list)
        # remove first 83 lines and end on line 676
        final_list = text_list[54:100]
        final_list= str(final_list)
        #print(color.BOLD +"\n Wordle Words:"+ color.END)
        ##removing all punctuations
        fixed_text = final_list.replace('$',' ')
        fixed_text = fixed_text.replace('&',' ')
        fixed_text = fixed_text.replace('%',' ')
        fixed_text = fixed_text.replace('-',' ')
        fixed_text = fixed_text.replace('_',' ')
        fixed_text = fixed_text.replace('=',' ')
        fixed_text = fixed_text.replace('+',' ')
        fixed_text = fixed_text.replace('<',' ')
        fixed_text = fixed_text.replace('>',' ')
        fixed_text = fixed_text.replace(''' " ''',' ')
        fixed_text = fixed_text.replace('(',' ')
        fixed_text = fixed_text.replace(')',' ')
        fixed_text = fixed_text.replace('~',' ')
        fixed_text = final_list.replace('\n',' ')  
        fixed_text = fixed_text.replace('.',' ')
        fixed_text = fixed_text.replace(';',' ')
        fixed_text = fixed_text.replace('?',' ')
        fixed_text = fixed_text.replace('!',' ')
        fixed_text = fixed_text.replace(',',' ')
        fixed_text = fixed_text.replace(':',' ')
        fixed_text = fixed_text.replace('*',' ')
        fixed_text = fixed_text.replace('/',' ')
        fixed_text = fixed_text.replace('[',' ')
        fixed_text = fixed_text.replace(']',' ')
        fixed_text = fixed_text.replace('#',' ')
        fixed_text = fixed_text.replace('@',' ')
        fixed_text = fixed_text.replace('\\',' ')
        fixed_text = fixed_text.replace("'",' ')
        fixed_text = fixed_text.replace("--",' ')
        fixed_text = fixed_text.replace("`",' ')
        fixed_text = fixed_text.replace('"',' ')
        
        #print(fixed_text)
        words_list= fixed_text.split()
        words_list1= [i.strip() for i in words_list]
        keys_1= list(words_count.keys())
        #print(words_list1)
        maximum= max(words_list1, key=len)
        #print(maximum)
        minimum= min(words_list1, key=len)
        #print(minimum)
        ##converting all to lower case
        for i in range(len(words_list1)):
            words_list1[i]= words_list1[i].lower()
        count += len(words_list1)
        for word in set(words_list1):
            count_1 += 1
        
        #print(num_words_2)total unique words
        ## finding average
        average1 = count/count_1
        #print(average1)
        for word in words_list1:
            if word.isalpha():
                if word in dict_x:
                    dict_x[word] += 1
                else:
                    dict_x[word] = 1
        #the top 10 longest words 
        long_words1=sorted(words_list1,key= len, reverse=True)
        #print(long_words)
        ##without duplication 
        long_words2= list(dict.fromkeys(long_words1))
        long_words_10= long_words2[:10]
        
        for  word in range (dict_x[word]):
            word= random.randrange(1,10)
            if word==1:
                num_1s += 1
            elif word==2:
                num_2s += 1
            elif word==3:
                num_3s += 1
            elif word==4:
                num_4s += 1
            elif word==5:
                num_5s += 1
            elif word==6:
                num_6s += 1
            elif word==7:
                num_7s += 1
            elif word==8:
                num_8s += 1
            elif word==9:
                num_9s += 1
        #print(long_words_10)
        print('====================================')
        print('ANALYSIS ON STATE OF UNION ADDRESS ')
        print('====================================')
        
        print('There are a total of',count, 'words in this selection.')
        print()
        print('There are', len(set(words_list1)), 'unique words in this selection.')
        print()
        print('The average word length is',  round(average1,2))
        print()
        print('The minimum length is', len(minimum) ,'and the maximum length is', len(maximum))
        print()
                
        long()
        print(long_words_10)    
                
        print("The longest word is", long_words_10[0], "and was found", long_words1.count(long_words_10[0]), "time")
        print("The 2nd is", long_words_10[1], "and was found", long_words1.count(long_words_10[1]), "time")
        print("The 3rd is", long_words_10[2], "and was found", long_words1.count(long_words_10[2]), "times")
        print("The 4th is", long_words_10[3], "and was found", long_words1.count(long_words_10[3]), "time")
        print("The 5th is", long_words_10[4], "and was found", long_words1.count(long_words_10[4]), "time")
        print("The 6th is", long_words_10[5], "and was found", long_words1.count(long_words_10[5]), "time")
        print("The 7th is", long_words_10[6], "and was found", long_words1.count(long_words_10[6]), "times")
        print("The 8th is", long_words_10[7], "and was found", long_words1.count(long_words_10[7]), "times")
        print("The 9th is", long_words_10[8], "and was found", long_words1.count(long_words_10[8]), "time")
        print("The 10th is", long_words_10[9], "and was found", long_words1.count(long_words_10[9]), "time")
        
        print()
        print('=======================================')
        chart()
        print('=======================================')
        print(f'Word       {"length of each word":>10}')
        print(f'{1:>4}      {num_1s:>10}')
        print(f'{2:>4}      {num_2s:>10}')
        print(f'{3:>4}      {num_3s:>10}')
        print(f'{4:>4}      {num_4s:>10}')
        print(f'{5:>4}      {num_5s:>10}')
        print(f'{6:>4}      {num_6s:>10}')
        print(f'{7:>4}      {num_7s:>10}')
        print(f'{8:>4}      {num_8s:>10}')
        print(f'{9:>4}      {num_9s:>10}')
        # display the results as a graph
             
        figure = plot.figure()  # start with a blank figure
        axes = figure.add_axes([1,1,2,2])
        labels = ['1','2','3','4','5','6','7','8','9']
        values = [num_1s,num_2s,num_3s,num_4s,num_5s,num_6s,num_7s,num_8s,num_9s]
        axes.bar(labels,values)
        axes.set_title('Number of words of each length')
        plot.show()
        
        print('==============================================================')
        cloud()
        print('==============================================================')
        from collections import Counter
        words_counts_1= Counter(words_list1)
        top_100= words_counts_1.most_common(100)
        word_dict= {i:u for i, u in enumerate(top_100)}
        unique_string= ','.join(str(v) for v in top_100)
        wordcloud= WordCloud(width=1000,height=500,colormap='prism', background_color='white').generate(unique_string)
        plot.figure(figsize=(15,8))
        plot.imshow(wordcloud)
        plot.axis("off")
        plot.savefig("your_file_name"+".png", bbox_inches='tight')
        plot.show()      

    elif user_input==4:
        print("Quit the program")
        break
    else:
        print("GOODBYE")
# Out:
# Choose from the following options:
#
#     Menu
#     1. Analysze a local, user specified file.
#     2. Connect to Project Gutenberg and analysze the U.S. Constitution.
#     3. Connect to Project Gutenberg and analyze the State of the Union Addresses for a specific President.
#     4. Quit the program
#
# Enter your choice: 1
# Analysze a local, user specified file.
# Enter a filename to open(file must be in current directory):  Macbeth.txt
# There are a total of 21074 words in this selection.
#
# There are 4154 unique words in this selection.
#
# The average word length is 5.07
#
# The minimum length is 1 and the maximum length is 15
#
# The 10 longest words are;
# ['merchantability', 'voluptuousnesse', 'electronically', 'capitalization', 'northumberland', 'transcription', 'consequential', 'alternatively', 'contributions', 'substitutions']
# The longest word is merchantability and was found 1 time
# The 2nd is voluptuousnesse and was found 1 time
# ...
